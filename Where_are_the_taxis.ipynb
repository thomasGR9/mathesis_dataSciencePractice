# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_filename = "../nyc_taxi_trip_data_sample.csv"
data_filename
# Out:
# '../nyc_taxi_trip_data_sample.csv'

# %%
data = pd.read_csv(data_filename)
data
# Out:
#                                 medallion                      hack_license  \
# 0        037CB433AB5895649F7A9EF37F767EF1  F57FA13A6A82FE2F40D9DB0193DE0FEE
# 1        E05E952B2DA14C7E9F1D7DEB80667739  11A3989B7BABB288FA3FA233E348C450
# 2        51B267141807D0261EEB1844D2A78087  9DE60DFD683336F899D5BB448CE7CB09
# 3        76AC5C0F44D07BA5A2291F19E730B0B9  2348E03BB8227595281D9D6B38E45B38
# 4        739323AC15DADABE4B54561CB3330C53  9387A0902D7B1B4597802BE63AE7C34F
# ...                                   ...                               ...
# 1731792  5DAE4FE51457F5B4D4950D00A0AD4394  B76DC9DC874EB9D71CC04ABC0D9AAC6A
# 1731793  3C16CFAD2B12F3508F7211C37F8F8B8F  A36B62F2B6D1D6C289519810E66EAAB9
# 1731794  23E5F1FDC96168E865BF7B4427C0163B  E7D75D6D6F2DBD7D25578F02991193D9
# 1731795  FE44D1131D86D515C88D5296598DD35A  015615BB1B66BA269602ED1A867271FA
# 1731796  465FE7E793D67BBB8A7A9869065170E5  E5D211ECD1F6A6164B6CFF1EB9B50499
#
# ...

# %%
data.shape
# Out:
# (1731797, 14)

# %%
data.head(3)
# Out:
#                           medallion                      hack_license  \
# 0  037CB433AB5895649F7A9EF37F767EF1  F57FA13A6A82FE2F40D9DB0193DE0FEE
# 1  E05E952B2DA14C7E9F1D7DEB80667739  11A3989B7BABB288FA3FA233E348C450
# 2  51B267141807D0261EEB1844D2A78087  9DE60DFD683336F899D5BB448CE7CB09
#
#   vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 0       VTS          1                NaN  2013-10-04 20:20:00
# 1       CMT          1                  N  2013-09-27 14:16:04
# 2       CMT          1                  N  2013-07-18 13:24:37
#
#       dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 0  2013-10-04 20:42:00                1               1320           4.05
# 1  2013-09-27 14:37:17                1               1273           2.10
# 2  2013-07-18 13:29:27                3                290           0.90
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# ...

# %%
data[:3]
# Out:
#                           medallion                      hack_license  \
# 0  037CB433AB5895649F7A9EF37F767EF1  F57FA13A6A82FE2F40D9DB0193DE0FEE
# 1  E05E952B2DA14C7E9F1D7DEB80667739  11A3989B7BABB288FA3FA233E348C450
# 2  51B267141807D0261EEB1844D2A78087  9DE60DFD683336F899D5BB448CE7CB09
#
#   vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 0       VTS          1                NaN  2013-10-04 20:20:00
# 1       CMT          1                  N  2013-09-27 14:16:04
# 2       CMT          1                  N  2013-07-18 13:24:37
#
#       dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 0  2013-10-04 20:42:00                1               1320           4.05
# 1  2013-09-27 14:37:17                1               1273           2.10
# 2  2013-07-18 13:29:27                3                290           0.90
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# ...

# %%
data.tail(3)
# Out:
#                                 medallion                      hack_license  \
# 1731794  23E5F1FDC96168E865BF7B4427C0163B  E7D75D6D6F2DBD7D25578F02991193D9
# 1731795  FE44D1131D86D515C88D5296598DD35A  015615BB1B66BA269602ED1A867271FA
# 1731796  465FE7E793D67BBB8A7A9869065170E5  E5D211ECD1F6A6164B6CFF1EB9B50499
#
#         vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 1731794       VTS          1                NaN  2013-02-16 17:24:00
# 1731795       CMT          1                  N  2013-05-24 10:29:16
# 1731796       CMT          1                  N  2013-03-15 14:42:10
#
#             dropoff_datetime  passenger_count  trip_time_in_secs  \
# 1731794  2013-02-16 17:30:00                3                360
# 1731795  2013-05-24 10:44:39                1                923
# 1731796  2013-03-15 14:51:20                1                549
#
#          trip_distance  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
data[-3:]
# Out:
#                                 medallion                      hack_license  \
# 1731794  23E5F1FDC96168E865BF7B4427C0163B  E7D75D6D6F2DBD7D25578F02991193D9
# 1731795  FE44D1131D86D515C88D5296598DD35A  015615BB1B66BA269602ED1A867271FA
# 1731796  465FE7E793D67BBB8A7A9869065170E5  E5D211ECD1F6A6164B6CFF1EB9B50499
#
#         vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 1731794       VTS          1                NaN  2013-02-16 17:24:00
# 1731795       CMT          1                  N  2013-05-24 10:29:16
# 1731796       CMT          1                  N  2013-03-15 14:42:10
#
#             dropoff_datetime  passenger_count  trip_time_in_secs  \
# 1731794  2013-02-16 17:30:00                3                360
# 1731795  2013-05-24 10:44:39                1                923
# 1731796  2013-03-15 14:51:20                1                549
#
#          trip_distance  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
data.describe()
# Out:
#           rate_code  passenger_count  trip_time_in_secs  trip_distance  \
# count  1.731797e+06     1.731797e+06       1.731797e+06   1.731797e+06
# mean   1.033927e+00     1.707519e+00       8.110141e+02   3.458005e+00
# std    4.174030e-01     1.373835e+00       1.561974e+04   7.221295e+02
# min    0.000000e+00     0.000000e+00      -1.000000e+01   0.000000e+00
# 25%    1.000000e+00     1.000000e+00       3.600000e+02   1.040000e+00
# 50%    1.000000e+00     1.000000e+00       6.000000e+02   1.800000e+00
# 75%    1.000000e+00     2.000000e+00       9.600000e+02   3.200000e+00
# max    2.100000e+02     7.000000e+00       4.294941e+06   9.500000e+05
#
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# count      1.731797e+06     1.731797e+06       1.731767e+06      1.731767e+06
# mean      -7.244724e+01     3.974714e+01      -7.240237e+01      3.972352e+01
# std        1.122722e+01     8.509423e+00       1.134113e+01      8.562259e+00
# ...

# %%
data.columns
# Out:
# Index(['medallion', 'hack_license', 'vendor_id', 'rate_code',
#        'store_and_fwd_flag', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'trip_time_in_secs', 'trip_distance',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude'],
#       dtype='object')

# %%
data.pickup_longitude
# Out:
# 0         -73.990089
# 1         -73.960022
# 2         -73.970634
# 3         -73.992661
# 4         -73.999107
#              ...
# 1731792   -73.995766
# 1731793     0.000000
# 1731794   -73.991554
# 1731795   -73.865715
# 1731796   -74.002968
# Name: pickup_longitude, Length: 1731797, dtype: float64

# %%
data['pickup_latitude']
# Out:
# 0          40.723377
# 1          40.710678
# 2          40.760410
# 3          40.752766
# 4          40.727924
#              ...
# 1731792    40.764359
# 1731793     0.000000
# 1731794    40.726940
# 1731795    40.771168
# 1731796    40.718216
# Name: pickup_latitude, Length: 1731797, dtype: float64

# %%
print(data['pickup_latitude'].min(), data['pickup_latitude'].max())
# Out:
# -3117.4944 74.00267

# %%
print(data['pickup_longitude'].min(), data['pickup_longitude'].max())
# Out:
# -740.02167 51.977318

# %%
data['pickup_latitude'] >= 0
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#            ...
# 1731792    True
# 1731793    True
# 1731794    True
# 1731795    True
# 1731796    True
# Name: pickup_latitude, Length: 1731797, dtype: bool

# %%
print(data.shape[0])
data[data['pickup_latitude'] >= 0]
# Out:
# 1731797
#                                 medallion                      hack_license  \
# 0        037CB433AB5895649F7A9EF37F767EF1  F57FA13A6A82FE2F40D9DB0193DE0FEE
# 1        E05E952B2DA14C7E9F1D7DEB80667739  11A3989B7BABB288FA3FA233E348C450
# 2        51B267141807D0261EEB1844D2A78087  9DE60DFD683336F899D5BB448CE7CB09
# 3        76AC5C0F44D07BA5A2291F19E730B0B9  2348E03BB8227595281D9D6B38E45B38
# 4        739323AC15DADABE4B54561CB3330C53  9387A0902D7B1B4597802BE63AE7C34F
# ...                                   ...                               ...
# 1731792  5DAE4FE51457F5B4D4950D00A0AD4394  B76DC9DC874EB9D71CC04ABC0D9AAC6A
# 1731793  3C16CFAD2B12F3508F7211C37F8F8B8F  A36B62F2B6D1D6C289519810E66EAAB9
# 1731794  23E5F1FDC96168E865BF7B4427C0163B  E7D75D6D6F2DBD7D25578F02991193D9
# 1731795  FE44D1131D86D515C88D5296598DD35A  015615BB1B66BA269602ED1A867271FA
# 1731796  465FE7E793D67BBB8A7A9869065170E5  E5D211ECD1F6A6164B6CFF1EB9B50499
#
# ...

# %%
data[(data['pickup_latitude']) >= 0 & (data['pickup_latitude'] <= 90)]
# Out:
#                                 medallion                      hack_license  \
# 0        037CB433AB5895649F7A9EF37F767EF1  F57FA13A6A82FE2F40D9DB0193DE0FEE
# 1        E05E952B2DA14C7E9F1D7DEB80667739  11A3989B7BABB288FA3FA233E348C450
# 2        51B267141807D0261EEB1844D2A78087  9DE60DFD683336F899D5BB448CE7CB09
# 3        76AC5C0F44D07BA5A2291F19E730B0B9  2348E03BB8227595281D9D6B38E45B38
# 4        739323AC15DADABE4B54561CB3330C53  9387A0902D7B1B4597802BE63AE7C34F
# ...                                   ...                               ...
# 1731792  5DAE4FE51457F5B4D4950D00A0AD4394  B76DC9DC874EB9D71CC04ABC0D9AAC6A
# 1731793  3C16CFAD2B12F3508F7211C37F8F8B8F  A36B62F2B6D1D6C289519810E66EAAB9
# 1731794  23E5F1FDC96168E865BF7B4427C0163B  E7D75D6D6F2DBD7D25578F02991193D9
# 1731795  FE44D1131D86D515C88D5296598DD35A  015615BB1B66BA269602ED1A867271FA
# 1731796  465FE7E793D67BBB8A7A9869065170E5  E5D211ECD1F6A6164B6CFF1EB9B50499
#
# ...

# %%
data = data[(data['pickup_latitude'] >= 0) & (data['pickup_latitude'] <= 90) & (data['pickup_longitude'] >= -180) & (data['pickup_longitude'] <= 0)]
data
# Out:
#                                 medallion                      hack_license  \
# 0        037CB433AB5895649F7A9EF37F767EF1  F57FA13A6A82FE2F40D9DB0193DE0FEE
# 1        E05E952B2DA14C7E9F1D7DEB80667739  11A3989B7BABB288FA3FA233E348C450
# 2        51B267141807D0261EEB1844D2A78087  9DE60DFD683336F899D5BB448CE7CB09
# 3        76AC5C0F44D07BA5A2291F19E730B0B9  2348E03BB8227595281D9D6B38E45B38
# 4        739323AC15DADABE4B54561CB3330C53  9387A0902D7B1B4597802BE63AE7C34F
# ...                                   ...                               ...
# 1731792  5DAE4FE51457F5B4D4950D00A0AD4394  B76DC9DC874EB9D71CC04ABC0D9AAC6A
# 1731793  3C16CFAD2B12F3508F7211C37F8F8B8F  A36B62F2B6D1D6C289519810E66EAAB9
# 1731794  23E5F1FDC96168E865BF7B4427C0163B  E7D75D6D6F2DBD7D25578F02991193D9
# 1731795  FE44D1131D86D515C88D5296598DD35A  015615BB1B66BA269602ED1A867271FA
# 1731796  465FE7E793D67BBB8A7A9869065170E5  E5D211ECD1F6A6164B6CFF1EB9B50499
#
# ...

# %%
def lng_lat_to_pixels(lng, lat):    
    lng_rad = lng * np.pi / 180
    lat_rad = lat * np.pi / 180
    x = (256/(2*np.pi))*(lng_rad + np.pi)
    y = (256/(2*np.pi))*(np.log(np.tan(np.pi/4 + lat_rad/2)))
    return (x, y)

# %%
px, py  = lng_lat_to_pixels(data['pickup_longitude'], data['pickup_latitude'])
px.head(10)
# Out:
# 0    75.384826
# 1    75.406207
# 2    75.398660
# 3    75.382997
# 4    75.378413
# 5    75.383789
# 6    75.384993
# 7    75.414177
# 8    75.391119
# 9    75.388048
# Name: pickup_longitude, dtype: float64

# %%
 plt.scatter(px, py)

# %%
plt.figure(figsize=(12, 10))
plt.axis('equal')
plt.xlim(75.35, 75.5)
plt.ylim(31.6, 31.95)
plt.axis('off')
plt.gca().set_facecolor('white')
plt.scatter(px, py, s=0.1, alpha=.03, color='black')

# %%
data['trip_distance'].count(), data['trip_distance'].min(), data['trip_distance'].max()
# Out:
# (1726326, 0.0, 950000.0)

# %%
data['trip_distance'].mean(), data['trip_distance'].median(), data['trip_distance'].std()
# Out:
# (3.4589482403668006, 1.8, 723.2727891363618)

# %%
data['trip_distance'].mode()
# Out:
# 0    1.0
# Name: trip_distance, dtype: float64

# %%
data['trip_distance'].value_counts()
# Out:
# 1.00     43398
# 0.90     38466
# 0.80     37634
# 1.10     37424
# 1.20     36037
#          ...
# 34.28        1
# 36.00        1
# 41.06        1
# 32.90        1
# 24.87        1
# Name: trip_distance, Length: 3000, dtype: int64

# %%
data['trip_distance'].value_counts()[:10]
# Out:
# 1.00     43398
# 0.90     38466
# 0.80     37634
# 1.10     37424
# 1.20     36037
#          ...
# 2.59      1347
# 2.64      1330
# 0.42      1323
# 2.61      1314
# 10.00     1312
# Name: trip_distance, Length: 275, dtype: int64

# %%
data['trip_distance'].value_counts().iloc[:10]
# Out:
# 1.0    43398
# 0.9    38466
# 0.8    37634
# 1.1    37424
# 1.2    36037
# 0.7    34577
# 1.3    33979
# 1.4    32454
# 1.5    31053
# 0.6    30342
# Name: trip_distance, dtype: int64

# %%
data['trip_distance'].value_counts().loc[:10]
# Out:
# 1.00     43398
# 0.90     38466
# 0.80     37634
# 1.10     37424
# 1.20     36037
#          ...
# 2.59      1347
# 2.64      1330
# 0.42      1323
# 2.61      1314
# 10.00     1312
# Name: trip_distance, Length: 275, dtype: int64

# %%
data.trip_distance.hist(color='blue', edgecolor='black', alpha=0.5, figsize=(10, 8))
# Out:
# <AxesSubplot:>

# %%
np.linspace(0, 10, 100)
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
data.trip_distance.hist(bins=np.linspace(0, 10, 100), color='blue', edgecolor='black', alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
data['trip_distance'].value_counts(bins=np.linspace(0, 10, 100))
# Out:
# (0.909, 1.01]     78411
# (0.808, 0.909]    68773
# (1.01, 1.111]     68208
# (0.707, 0.808]    66331
# (1.111, 1.212]    65878
#                   ...
# (9.697, 9.798]     2014
# (7.879, 7.98]      2001
# (8.485, 8.586]     1993
# (8.283, 8.384]     1974
# (9.798, 9.899]     1965
# Name: trip_distance, Length: 99, dtype: int64

# %%
trip_distance_counts = data['trip_distance'].value_counts(bins=np.linspace(0, 10 , 100)).sort_index()
trip_distance_counts
# Out:
# (-0.001, 0.101]    16964
# (0.101, 0.202]      7719
# (0.202, 0.303]     13077
# (0.303, 0.404]     24109
# (0.404, 0.505]     37384
#                    ...
# (9.495, 9.596]      2133
# (9.596, 9.697]      2019
# (9.697, 9.798]      2014
# (9.798, 9.899]      1965
# (9.899, 10.0]       3205
# Name: trip_distance, Length: 99, dtype: int64

# %%
from scipy.signal import find_peaks
peaks, _ = find_peaks(trip_distance_counts)
peaks
# Out:
# array([ 9, 19, 29, 39, 49, 59, 69, 79, 83, 89, 91, 93])

# %%
trip_distance_counts.iloc[peaks]
# Out:
# (0.909, 1.01]     78411
# (1.919, 2.02]     46829
# (2.929, 3.03]     23002
# (3.939, 4.04]     12517
# (4.949, 5.051]     7301
# (5.96, 6.061]      4734
# (6.97, 7.071]      3021
# (7.98, 8.081]      2336
# (8.384, 8.485]     2018
# (8.99, 9.091]      2414
# (9.192, 9.293]     2159
# (9.394, 9.495]     2139
# Name: trip_distance, dtype: int64

# %%
distance_hist = data.trip_distance.hist(bins=np.linspace(0, 10, 100), color='blue', edgecolor='black', alpha=0.5)

for i in peaks:
    distance_hist.patches[i].set_facecolor('red')

# %%
# Out:
#   File "/tmp/ipykernel_3442/2294110517.py", line 1
#     SELECT Column1, Column2, mean(Column3), sum(Column4)
#            ^
# SyntaxError: invalid syntax
